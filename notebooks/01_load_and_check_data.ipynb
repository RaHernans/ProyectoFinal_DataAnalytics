# %% [markdown]
# # Proyecto Final – Análisis de Ventas Retail (Global Superstore)
# Este notebook corresponde a la fase de carga y validación inicial de los datos.
# Se utilizan dos conjuntos de datos en bruto que posteriormente serán transformados
# y analizados.

# %% [markdown]
# # Importación de librerías.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Carga de datos

# %%
sales = pd.read_csv(
    "../data/raw_data/global_superstore.csv",
    encoding="latin1"
)

countries = pd.read_csv("../data/raw_data/countries.csv")

# %% [markdown]
# # Validación de datos

# %%
sales.shape, countries.shape
# Out:
# ((51290, 24), (227, 20))

# %%
sales.head()
countries.head()
sales.info()
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
"Country" in sales.columns, "Country" in countries.columns
# Out:
# (True, True)

# %% [markdown]
# # EDA inicial
# Se realiza un análisis exploratorio básico para identificar patrones, valores nulos, duplicados y posibles transformaciones necesarias.

# %%
sales.describe()
sales.isna().sum()
sales.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicados
# Tras analizar el conjunto de datos de ventas, no se han detectado registros duplicados. Por lo tanto, no es necesarios aplicar ningún tratamiento adicional.
